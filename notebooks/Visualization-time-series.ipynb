# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from numpy import random
import datetime

import functools
import seaborn as sns

from sklearn import preprocessing, cross_validation, svm
from sklearn.linear_model import LinearRegression

import quandl
import math

import pyflux as pf

# %%
house_file = 'house_1_avg_60.csv'

# %%
frames = []

df = pd.read_table(house_file, parse_dates=True,
                               header=0,
                               index_col=0,
                               sep=",",
                               decimal=".")

# plt.figure(figsize=(15, 5))
# plt.plot(df['5refrigerator'][:100])
# plt.ylabel('Consumption')
# plt.xlabel('Date')
# plt.title('Device consumption');

model = pf.ARIMA(data=df[:20], ar=4, ma=4, target='5refrigerator', family=pf.Normal())

x = model.fit("MLE")
x.summary()

# model.plot_z(figsize=(15,5))
model.plot_fit(figsize=(15, 10))
# model.plot_predict_is(h=50, figsize=(15, 5))
# Out:
# Normal ARIMA(4,0,4)
# ======================================================= ==================================================
# Dependent Variable: 5refrigerator                       Method: MLE
# Start Date: 2011-04-18 13:26:00                         Log Likelihood: 38.5759
# End Date: 2011-04-18 13:41:00                           AIC: -57.1519
# Number of observations: 16                              BIC: -49.426
# ...
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Constant                                 6.0941     1.8318     3.3268   0.0009   (2.5038 | 9.6845)
# AR(1)                                    0.7231     0.1461     4.9511   0.0      (0.4369 | 1.0094)
# AR(2)                                    -0.6958    0.034      -20.474  0.0      (-0.7624 | -0.6291)
# ...
